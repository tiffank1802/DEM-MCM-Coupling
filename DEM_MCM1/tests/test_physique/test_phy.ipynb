# %%
import sys
from pathlib import Path

root_path = Path.cwd()
for parent in [root_path] + list(root_path.parents):
    if (parent / "src").exists():
        root_path = parent
        break
else:
    raise FileNotFoundError("Could not find repo root containing src")

if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))

# %%
import pyvista as pv
import numpy as np
import streamlit as st
from stpyvista import stpyvista
from src.Markov import Markov
# Out:
# ---------------------------------------------------------------------------
# StreamlitAPIException                     Traceback (most recent call last)
# Cell In[6], line 4
#       2 import numpy as np
#       3 import streamlit as st
# ----> 4 from stpyvista import stpyvista
#       5 from src.Markov import Markov
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/stpyvista/__init__.py:29
#      22 # Declare component to create callable
#      23 _html = (
#      24     '<div id="stpyvistadiv">'
#      25     '<iframe id="stpyvistaframe" frameborder="0" allowfullscreen allowtransparency referrerpolicy="same-origin">'
#      26     "</iframe></div>"
#      27 )
# ---> 29 _stpv_component = component(
#      30     "stpyvista.simple",
#      31     html=_html,
#      32     js="v2/stpyvista.js",
#      33     css="v2/style.css",
#      34     isolate_styles=True,
#      35 )
#      37 # Expose this to streamlit user
#      38 def stpyvista(
#      39     plotter: Plotter,
#      40     backend: Literal["panel", "trame"] = "trame",
#    (...)
#      43     key: Optional[str] = None,
#      44 ) -> None:
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/streamlit/components/v2/__init__.py:524, in component(name, html, css, js, isolate_styles)
#     207 def component(
#     208     name: str,
#     209     *,
#    (...)
#     213     isolate_styles: bool = True,
#     214 ) -> ComponentRenderer:
#     215     '''Register an ``st.components.v2`` component and return a callable to mount it.
#     216
#     217     Components can have any combination of HTML, CSS, and JavaScript. If none
#    (...)
#     522
#     523     '''
# --> 524     return _create_component_callable(
#     525         name, html=html, css=css, js=js, isolate_styles=isolate_styles
#     526     )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/streamlit/components/v2/__init__.py:141, in _create_component_callable(name, html, css, js, isolate_styles)
#     104 def _create_component_callable(
#     105     name: str,
#     106     *,
#    (...)
#     110     isolate_styles: bool = True,
#     111 ) -> Callable[..., Any]:
#     112     """Create a component callable, handling both lookup and registration cases.
#     113
#     114     Parameters
#    (...)
#     139         If a component is not found in the registry.
#     140     """
# --> 141     component_key = _register_component(name=name, html=html, css=css, js=js)
#     143     # The inner callable that mounts the component.
#     144     def _mount_component(
#     145         *,
#     146         key: str | None = None,
#    (...)
#     151         **on_callbacks: WidgetCallback | None,
#     152     ) -> ComponentResult:
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/streamlit/components/v2/__init__.py:89, in _register_component(name, html, css, js)
#      85 component_key = name
#      87 manager = get_bidi_component_manager()
#      88 manager.register(
# ---> 89     build_definition_with_validation(
#      90         manager=manager,
#      91         component_key=component_key,
#      92         html=html,
#      93         css=css,
#      94         js=js,
#      95     )
#      96 )
#      98 # Record API inputs for future re-resolution on file changes
#      99 manager.record_api_inputs(component_key, css, js)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/streamlit/components/v2/component_definition_resolver.py:132, in build_definition_with_validation(manager, component_key, html, css, js)
#     129     rel_url = str(resolved_candidate.relative_to(asset_root.resolve()).as_posix())
#     130     return str(resolved_candidate), rel_url
# --> 132 css_value, css_rel = _resolve_entry(css, kind="css")
#     133 js_value, js_rel = _resolve_entry(js, kind="js")
#     135 # Build definition with possible asset_dir-relative paths
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/streamlit/components/v2/component_definition_resolver.py:107, in build_definition_with_validation.<locals>._resolve_entry(value, kind)
#     105 # For path-like strings, asset_root must exist
#     106 if asset_root is None:
# --> 107     raise StreamlitAPIException(
#     108         f"Component '{component_key}' must be declared in pyproject.toml with asset_dir "
#     109         f"to use file-backed {kind}."
#     110     )
#     112 value_str = value
#     114 # If looks like a glob, resolve strictly inside asset_root
#
# StreamlitAPIException: Component 'stpyvista.simple' must be declared in pyproject.toml with asset_dir to use file-backed css.

# %%
datas=load_parquet_as_timestep_dict()
